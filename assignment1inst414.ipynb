# %%
import requests
import xml.etree.ElementTree as ET

# %%
BOX = 0.01

# %%
url = "http://www.overpass-api.de/api/xapi?way[highway=path|track|footway|steps|bridleway|cycleway][bbox=-75.0,40.0,-74.99,40.01]"
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.headers['content-type']
# Out:
# 'application/osm3s+xml'

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<osm version="0.6" generator="Overpass API 0.7.61.5 4133829e">\n<note>The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.</note>\n<meta osm_base="2023-09-14T20:03:05Z"/>\n\n  <node id="411074711" lat="40.0072417" lon="-74.9951011"/>\n  <node id="411074733" lat="40.0069563" lon="-74.9980488"/>\n  <node id="6979870197" lat="40.0065401" lon="-74.9978480"/>\n  <node id="6979870204" lat="40.0066227" lon="-74.9977470"/>\n  <node id="6979870221" lat="40.0068217" lon="-74.9953642"/>\n  <node id="7265394479" lat="40.0048222" lon="-74.9987746"/>\n  <node id="7265394480" lat="40.0049111" lon="-74.9985060"/>\n  <node id="7265394481" lat="40.0051704" lon="-74.9981207"/>\n  <node id="7265394482" lat="40.0052804" lon="-74.9979071"/>\n  <node id="7265394483" lat="40.0054467" lon="-74.9976012"/>\n  <node id="7265394484" lat="40.0055630" lon="-74.9974424"/>\n  <node id="7265394485" lat="40.0056238" lon="-74.
# ...

# %%
root = ET.fromstring(response.text)

# %%
paths = len(root.findall(".//way"))

# %%
area = BOX * BOX
density = paths / area

# %%
print(f"Number of paths: {path_count}")
print(f"Path Density: {density} paths per square unit (e.g., per square meter)")
# Out:
# Number of paths: 48
# Path Density: 480000.0 paths per square unit (e.g., per square meter)
